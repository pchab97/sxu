# %%
import numpy as np
import pandas as pd

# %%
cars = pd.read_csv('samochody1tys.csv')

# %%
#Stworzenie serii z domyślnym indexem
s = pd.Series([1, 3, 5, "HelloWorld", 6, 8])
s

# %%
#Stworzenie struktury danych
dates = pd.date_range('20200101', periods=12)
print(dates)
print("______________")
df = pd.DataFrame(np.random.randn(12, 4), index=dates, columns=list('ABCD'))
df
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12'],
#               dtype='datetime64[ns]', freq='D')
# ______________
#                    A         B         C         D
# 2020-01-01  1.593143 -0.063327  0.698895 -0.421041
# 2020-01-02 -0.133951  1.418874 -0.021459  0.871480
# 2020-01-03 -1.097153 -0.786652  0.211856 -0.147966
# 2020-01-04 -0.213220  1.051219 -2.070451  0.343541
# 2020-01-05  0.459727 -0.353111 -1.750619  1.618127
# 2020-01-06 -2.198863  1.050891  0.746395 -0.512246
# 2020-01-07 -1.549727  0.855613  0.355406 -0.502326
# 2020-01-08 -0.348544 -1.411310  0.859161 -0.558039
# 2020-01-09  1.368025  0.290548  0.422564  0.596926
# 2020-01-10 -0.552830 -1.898704 -2.017893  0.540022
# 2020-01-11 -0.957884  0.091036 -0.954837 -0.434943
# 2020-01-12 -0.796979 -0.989593 -0.010310 -2.359474

# %%
#Stworzenie struktury danych przez przekazanie obiektów:
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20200101'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test1", "test2", "test3", "test4"]),
                    'F': 'foo'})

print(df2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2020-01-01  1.0  3  test1  foo
# 1  1.0 2020-01-01  1.0  3  test2  foo
# 2  1.0 2020-01-01  1.0  3  test3  foo
# 3  1.0 2020-01-01  1.0  3  test4  foo

# %%
#Wyswietlenie pierwszych pięciu i ostatnich trzech linii z tabeli
print(cars.head())
print("------------------------")
print(cars.tail(3))
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie
# ------------------------
#       id    marka    model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 997  997  Renault    Modus         2004.0        Benzyna             1200.0
# 998  998     Audi    A3 8L         2000.0        Benzyna             1595.0
# ...

# %%
#Wyświetlenie informacji o indexach i nazw kolumn
print(cars.index)
print(cars.columns)
# Out:
# RangeIndex(start=0, stop=1000, step=1)
# Index(['id', 'marka', 'model', 'rok_produkcji', 'rodzaj_silnika',
#        'pojemnosc_silnika', 'przebieg', 'cena', 'wojewodztwo'],
#       dtype='object')

# %%
#Rzutowanie danych do tablicy
cars.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
#Przedstawienie statystyk tablicy
cars.describe()
# Out:
#                 id  rok_produkcji  pojemnosc_silnika       przebieg  \
# count  1000.000000    1000.000000        1000.000000    1000.000000
# mean    499.500000    2009.009000        2040.065000  132556.677000
# std     288.819436       5.907946        6014.545066   90094.944138
# min       0.000000    1979.000000           1.000000       1.000000
# 25%     249.750000    2005.000000        1500.000000   51750.000000
# 50%     499.500000    2009.000000        1800.000000  149000.000000
# 75%     749.250000    2014.000000        2000.000000  193000.000000
# max     999.000000    2017.000000      191000.000000  647000.000000
#
#                 cena
# count    1000.000000
# mean    51942.181000
# std     70057.918015
# min       650.000000
# 25%     14900.000000
# 50%     27250.000000
# 75%     58900.000000
# max    616000.000000

# %%
#Transpozycja danych
cars.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
#Sortowanie według osi
cars.sort_index(axis=1, ascending=False)
# Out:
#         wojewodztwo  rok_produkcji rodzaj_silnika  przebieg  \
# 0      Dolnośląskie         2014.0         Diesel  160000.0
# 1    Świętokrzyskie         2012.0         Diesel  149000.0
# 2          Opolskie         2004.0    Benzyna+CNG   99000.0
# 3           Łódzkie         2008.0        Benzyna   93000.0
# 4     Wielkopolskie         2010.0         Diesel  127428.0
# ..              ...            ...            ...       ...
# 995     Małopolskie         2009.0         Diesel  182000.0
# 996       Lubelskie         2012.0        Benzyna   42700.0
# 997         Łódzkie         2004.0        Benzyna  168111.0
# 998     Małopolskie         2000.0        Benzyna  226500.0
# 999     Małopolskie         2016.0         Diesel   13617.0
#
#      pojemnosc_silnika        model       marka   id      cena
# 0               1600.0  X-Trail III      Nissan    0   75900.0
# 1               2000.0       X1 E84         BMW    1   70900.0
# ...

# %%
#Sortowanie według roku produkcji
cars.sort_values(by='marka')
# Out:
#       id       marka       model  rok_produkcji rodzaj_silnika  \
# 370  370  Alfa Romeo         159         2007.0         Diesel
# 300  300  Alfa Romeo         147         2002.0        Benzyna
# 705  705  Alfa Romeo      Spider         1995.0    Benzyna+LPG
# 213  213  Alfa Romeo         156         2004.0         Diesel
# 995  995  Alfa Romeo         159         2009.0         Diesel
# ..   ...         ...         ...            ...            ...
# 313  313       Škoda    Fabia II         2013.0         Diesel
# 733  733       Škoda  Octavia II         2010.0        Benzyna
# 978  978       Škoda    Fabia II         2014.0         Diesel
# 346  346       Škoda     Fabia I         2002.0        Benzyna
# 319  319       Škoda  Octavia II         2006.0        Benzyna
#
#      pojemnosc_silnika  przebieg     cena    wojewodztwo
# 370             1900.0  190000.0  19000.0    Mazowieckie
# 300             2000.0  200000.0   4100.0      Lubelskie
# ...

# %%
#Przedstawienie wybranej kolumny
cars["model"]
# Out:
# 0      X-Trail III
# 1           X1 E84
# 2         Zafira A
# 3            i10 I
# 4               CC
#           ...
# 995            159
# 996       Fabia II
# 997          Modus
# 998          A3 8L
# 999        XC 60 I
# Name: model, Length: 1000, dtype: object

# %%
#Przedstawienie wybranych wierszy
cars[100: 120]
# Out:
#       id          marka       model  rok_produkcji rodzaj_silnika  \
# 100  100     Volkswagen    Touran I         2003.0        Benzyna
# 101  101        Hyundai       i10 I         2009.0        Benzyna
# 102  102     Mitsubishi         ASX         2014.0         Diesel
# 103  103           Audi       A4 B7         2007.0         Diesel
# 104  104           Opel      Antara         2009.0         Diesel
# 105  105         Suzuki        Alto         2002.0        Benzyna
# 106  106        Citroën  Berlingo I         2005.0         Diesel
# 107  107     Volkswagen    Polo III         2001.0        Benzyna
# 108  108           Opel    Zafira B         2009.0         Diesel
# 109  109        Peugeot        2008         2017.0        Benzyna
# 110  110     Volkswagen    Touran I         2005.0         Diesel
# 111  111        Renault   Megane II         2007.0        Benzyna
# 112  112          Mazda        3 II         2009.0         Diesel
# ...

# %%
#Przedstawienie wybranych kolumn
cars.loc[:, ['id', 'marka']]
# Out:
#       id       marka
# 0      0      Nissan
# 1      1         BMW
# 2      2        Opel
# 3      3     Hyundai
# 4      4  Volkswagen
# ..   ...         ...
# 995  995  Alfa Romeo
# 996  996       Škoda
# 997  997     Renault
# 998  998        Audi
# 999  999       Volvo
#
# [1000 rows x 2 columns]

# %%
#Przedstawienie wybranych danych (wierszy i kolumn)
cars.loc[100 : 109, ['marka', 'model']]
# Out:
#           marka       model
# 100  Volkswagen    Touran I
# 101     Hyundai       i10 I
# 102  Mitsubishi         ASX
# 103        Audi       A4 B7
# 104        Opel      Antara
# 105      Suzuki        Alto
# 106     Citroën  Berlingo I
# 107  Volkswagen    Polo III
# 108        Opel    Zafira B
# 109     Peugeot        2008

# %%
#Wyświetlenie wartości wybranego obiektu
cars.loc[111, 'marka']
# Out:
# 'Renault'

# %%
#Wyświetlenie wartości wybranego obiektu z użyciem innej metody
cars.at[111, 'marka']
# Out:
# 'Renault'

# %%
#Wyświetlenie obiektu na podstawie indexu
cars.iloc[3]
# Out:
# id                         3
# marka                Hyundai
# model                  i10 I
# rok_produkcji           2008
# rodzaj_silnika       Benzyna
# pojemnosc_silnika       1100
# przebieg               93000
# cena                   11900
# wojewodztwo          Łódzkie
# Name: 3, dtype: object

# %%
#Wyświetlenie wierszy oraz kolumn z tabeli
cars.iloc[1:5, 1:5]
# Out:
#         marka     model  rok_produkcji rodzaj_silnika
# 1         BMW    X1 E84         2012.0         Diesel
# 2        Opel  Zafira A         2004.0    Benzyna+CNG
# 3     Hyundai     i10 I         2008.0        Benzyna
# 4  Volkswagen        CC         2010.0         Diesel

# %%
#Wyświetlanie wierszy
cars.iloc[1:5, :]
# Out:
#    id       marka     model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 1   1         BMW    X1 E84         2012.0         Diesel             2000.0
# 2   2        Opel  Zafira A         2004.0    Benzyna+CNG             1600.0
# 3   3     Hyundai     i10 I         2008.0        Benzyna             1100.0
# 4   4  Volkswagen        CC         2010.0         Diesel             1968.0
#
#    przebieg     cena     wojewodztwo
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie
# 3   93000.0  11900.0         Łódzkie
# 4  127428.0  49900.0   Wielkopolskie

# %%
#Wyświetlanie kolumn
cars.iloc[:, 1:3]
# Out:
#           marka        model
# 0        Nissan  X-Trail III
# 1           BMW       X1 E84
# 2          Opel     Zafira A
# 3       Hyundai        i10 I
# 4    Volkswagen           CC
# ..          ...          ...
# 995  Alfa Romeo          159
# 996       Škoda     Fabia II
# 997     Renault        Modus
# 998        Audi        A3 8L
# 999       Volvo      XC 60 I
#
# [1000 rows x 2 columns]

# %%
#Wyświetlenie wybranej komórki
cars.iloc[1, 1]
# Out:
# 'BMW'

# %%
#Wyświetlenie wybranej komórki za pomocą szybszej metody
cars.iat[1, 1]
# Out:
# 'BMW'

# %%
#Wyświetlenie danych, które spełniają kryteria
cars[cars.pojemnosc_silnika > 1900.0]
# Out:
#       id          marka         model  rok_produkcji rodzaj_silnika  \
# 1      1            BMW        X1 E84         2012.0         Diesel
# 4      4     Volkswagen            CC         2010.0         Diesel
# 6      6         Nissan     X-Trail I         2004.0         Diesel
# 8      8     Volkswagen            CC         2014.0         Diesel
# 11    11            BMW   Seria 5 E39         2002.0         Diesel
# ..   ...            ...           ...            ...            ...
# 989  989            BMW   Seria 5 E39         2002.0         Diesel
# 990  990  Mercedes-Benz  Klasa S W126         1986.0    Benzyna+LPG
# 994  994           Fiat      Bravo II         2007.0         Diesel
# 995  995     Alfa Romeo           159         2009.0         Diesel
# 999  999          Volvo       XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
#Filtrowanie wybranych danych z tabeli
cars[cars['marka'].isin(['Fiat', 'Volvo'])]
# Out:
#       id  marka         model  rok_produkcji rodzaj_silnika  \
# 5      5   Fiat           500         2014.0    Elektryczny
# 23    23  Volvo           V50         2011.0         Diesel
# 24    24  Volvo        S40 II         2008.0         Diesel
# 26    26  Volvo         S60 I         2003.0         Diesel
# 31    31   Fiat       Doblo I         2002.0        Benzyna
# 43    43  Volvo         XC 60         2017.0         Diesel
# 45    45  Volvo       XC 60 I         2016.0         Diesel
# 72    72  Volvo           V90         2016.0         Diesel
# 129  129   Fiat  Grande Punto         2006.0        Benzyna
# 146  146  Volvo         V40 I         2000.0         Diesel
# 167  167   Fiat       Tipo II         2016.0        Benzyna
# 195  195  Volvo         V40 I         2001.0         Diesel
# 208  208   Fiat      Bravo II         2007.0         Diesel
# 210  210   Fiat       Doblo I         2002.0         Diesel
# 233  233   Fiat        Sedici         2007.0         Diesel
# ...

# %%
#Zmiana nowej kolumny, automatycznie wyrównanie danych według indeksów
pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20200101', periods=6))
# Out:
# 2020-01-01    1
# 2020-01-02    2
# 2020-01-03    3
# 2020-01-04    4
# 2020-01-05    5
# 2020-01-06    6
# Freq: D, dtype: int64

# %%
#Zmiana wartości komórki w tabeli
df.at[dates[0], 'A'] = 0
df
# Out:
#                    A         B         C         D
# 2020-01-01  0.000000 -0.063327  0.698895 -0.421041
# 2020-01-02 -0.133951  1.418874 -0.021459  0.871480
# 2020-01-03 -1.097153 -0.786652  0.211856 -0.147966
# 2020-01-04 -0.213220  1.051219 -2.070451  0.343541
# 2020-01-05  0.459727 -0.353111 -1.750619  1.618127
# 2020-01-06 -2.198863  1.050891  0.746395 -0.512246
# 2020-01-07 -1.549727  0.855613  0.355406 -0.502326
# 2020-01-08 -0.348544 -1.411310  0.859161 -0.558039
# 2020-01-09  1.368025  0.290548  0.422564  0.596926
# 2020-01-10 -0.552830 -1.898704 -2.017893  0.540022
# 2020-01-11 -0.957884  0.091036 -0.954837 -0.434943
# 2020-01-12 -0.796979 -0.989593 -0.010310 -2.359474

# %%
#Zmiana wartości komórki przez podanie 
df.iat[1, 1] = 0
df
# Out:
#                    A         B         C         D
# 2020-01-01  0.000000  0.000000  0.698895 -0.421041
# 2020-01-02 -0.133951  0.000000 -0.021459  0.871480
# 2020-01-03 -1.097153 -0.786652  0.211856 -0.147966
# 2020-01-04 -0.213220  1.051219 -2.070451  0.343541
# 2020-01-05  0.459727 -0.353111 -1.750619  1.618127
# 2020-01-06 -2.198863  1.050891  0.746395 -0.512246
# 2020-01-07 -1.549727  0.855613  0.355406 -0.502326
# 2020-01-08 -0.348544 -1.411310  0.859161 -0.558039
# 2020-01-09  1.368025  0.290548  0.422564  0.596926
# 2020-01-10 -0.552830 -1.898704 -2.017893  0.540022
# 2020-01-11 -0.957884  0.091036 -0.954837 -0.434943
# 2020-01-12 -0.796979 -0.989593 -0.010310 -2.359474

# %%
#Zmiana wartości za pomocą tablicy NumPy:
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D
# 2020-01-01  0.000000  0.000000  0.698895  5
# 2020-01-02 -0.133951  0.000000 -0.021459  5
# 2020-01-03 -1.097153 -0.786652  0.211856  5
# 2020-01-04 -0.213220  1.051219 -2.070451  5
# 2020-01-05  0.459727 -0.353111 -1.750619  5
# 2020-01-06 -2.198863  1.050891  0.746395  5
# 2020-01-07 -1.549727  0.855613  0.355406  5
# 2020-01-08 -0.348544 -1.411310  0.859161  5
# 2020-01-09  1.368025  0.290548  0.422564  5
# 2020-01-10 -0.552830 -1.898704 -2.017893  5
# 2020-01-11 -0.957884  0.091036 -0.954837  5
# 2020-01-12 -0.796979 -0.989593 -0.010310  5

# %%
#Zmiana wartości komórek, które spełniają kryteria
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D
# 2020-01-01  0.000000  0.000000 -0.698895 -5
# 2020-01-02 -0.133951  0.000000 -0.021459 -5
# 2020-01-03 -1.097153 -0.786652 -0.211856 -5
# 2020-01-04 -0.213220 -1.051219 -2.070451 -5
# 2020-01-05 -0.459727 -0.353111 -1.750619 -5
# 2020-01-06 -2.198863 -1.050891 -0.746395 -5
# 2020-01-07 -1.549727 -0.855613 -0.355406 -5
# 2020-01-08 -0.348544 -1.411310 -0.859161 -5
# 2020-01-09 -1.368025 -0.290548 -0.422564 -5
# 2020-01-10 -0.552830 -1.898704 -2.017893 -5
# 2020-01-11 -0.957884 -0.091036 -0.954837 -5
# 2020-01-12 -0.796979 -0.989593 -0.010310 -5

# %%
#Stworzenie tabeli z wartością NaN
df3 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df3.loc[dates[0]:dates[1], 'E'] = 1
df3
# Out:
#                    A         B         C  D    E
# 2020-01-01  0.000000  0.000000  0.698895  5  1.0
# 2020-01-02 -0.133951  0.000000 -0.021459  5  1.0
# 2020-01-03 -1.097153 -0.786652  0.211856  5  NaN
# 2020-01-04 -0.213220  1.051219 -2.070451  5  NaN

# %%
#Usunięcie wiersz z wartością "NaN"
df3.dropna(how='any')
# Out:
#                    A    B         C  D    E
# 2020-01-01  0.000000  0.0  0.698895  5  1.0
# 2020-01-02 -0.133951  0.0 -0.021459  5  1.0

# %%
#Zmiana wartości pustych komórek
df3.fillna(value=8)
# Out:
#                    A         B         C  D    E
# 2020-01-01  0.000000  0.000000  0.698895  5  1.0
# 2020-01-02 -0.133951  0.000000 -0.021459  5  1.0
# 2020-01-03 -1.097153 -0.786652  0.211856  5  8.0
# 2020-01-04 -0.213220  1.051219 -2.070451  5  8.0

# %%
#Sprawdzenie, które komórki mają wartość "NaN"
pd.isna(df3)
# Out:
#                 A      B      C      D      E
# 2020-01-01  False  False  False  False  False
# 2020-01-02  False  False  False  False  False
# 2020-01-03  False  False  False  False   True
# 2020-01-04  False  False  False  False   True

# %%
#Wykonanie statystyki
df.mean()
# Out:
# A   -0.501783
# B   -0.175005
# C   -0.294274
# D    5.000000
# dtype: float64

# %%
#Wykonywanie statystyki opisowej dla wybranej osi:
df.mean(1)
# Out:
# 2020-01-01    1.424724
# 2020-01-02    1.211147
# 2020-01-03    0.832013
# 2020-01-04    0.941887
# 2020-01-05    0.838999
# 2020-01-06    1.149606
# 2020-01-07    1.165323
# 2020-01-08    1.024827
# 2020-01-09    1.770284
# 2020-01-10    0.132643
# 2020-01-11    0.794579
# 2020-01-12    0.800779
# Freq: D, dtype: float64

# %%
#Zastosowanie funkcji do danych
df.apply(np.cumsum)
df.apply(lambda x: x.max() - x.min())
# Out:
# A    3.566888
# B    2.949923
# C    2.929612
# D    0.000000
# dtype: float64

# %%
#Obliczenie wartości histogramu tablicy
s = pd.Series(np.random.randint(0, 7, size=10))
print(s)
s.value_counts()
# Out:
# 0    5
# 1    2
# 2    2
# 3    5
# 4    2
# 5    5
# 6    3
# 7    3
# 8    0
# 9    4
# dtype: int64
# 5    3
# 2    3
# 3    2
# 4    1
# 0    1
# dtype: int64

# %%
#Zmiana dużych liter na małe
s = pd.Series(['A', 'B', 'C', 'AaAa', 'Baba', np.nan, 'CACA'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaaa
# 4    baba
# 5     NaN
# 6    caca
# dtype: object

# %%
#Łączenie obiektów typu pandas
df = pd.DataFrame(np.random.randn(10, 4))
print(df, '\n')

pieces = [df[:3], df[3:7], df[7:]]
print(pieces, '\n')

pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.055195  0.717198  0.112633  0.664936
# 1 -0.134188 -2.047903 -0.337729 -0.110719
# 2  0.465830 -0.346175 -0.235702 -0.555060
# 3  0.746472  0.417729  1.014690  0.591875
# 4 -1.431189  0.587738  0.730972 -0.644962
# 5  0.280053 -0.907183 -1.187172  0.486519
# 6 -1.365910 -1.027621  0.111523  0.896792
# 7  2.015134  0.019558  1.146279  1.132004
# 8 -0.096954  0.773100  0.617363 -0.755576
# 9  0.166737 -0.104360 -0.934746  0.826555
#
# [          0         1         2         3
# 0  0.055195  0.717198  0.112633  0.664936
# 1 -0.134188 -2.047903 -0.337729 -0.110719
# 2  0.465830 -0.346175 -0.235702 -0.555060,           0         1         2         3
# 3  0.746472  0.417729  1.014690  0.591875
# 4 -1.431189  0.587738  0.730972 -0.644962
# 5  0.280053 -0.907183 -1.187172  0.486519
# 6 -1.365910 -1.027621  0.111523  0.896792,           0         1         2         3
# 7  2.015134  0.019558  1.146279  1.132004
# ...

# %%
#Łączenie danych inną metodą 
left = pd.DataFrame({'key': ['aaa', 'aaa'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['aaa', 'aaa'], 'rval': [4, 5]})

print(left,'\n')
print(right,'\n')
print(pd.merge(left, right, on='key'))
# Out:
#    key  lval
# 0  aaa     1
# 1  aaa     2
#
#    key  rval
# 0  aaa     4
# 1  aaa     5
#
#    key  lval  rval
# 0  aaa     1     4
# 1  aaa     1     5
# 2  aaa     2     4
# 3  aaa     2     5

# %%
#Dodanie na końcu
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
print(df,'\n')
s = df.iloc[3]
print(s,'\n')
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.842052  1.762629  0.887660  0.842017
# 1  0.380571  0.699405 -0.003666  0.866433
# 2  0.778278  0.457514  0.022936  1.169655
# 3  0.067449  1.364135 -1.229525 -1.215325
# 4  1.322887  1.112732  0.099083 -0.406288
# 5  0.075202 -0.099033 -0.415068 -0.889127
# 6  1.144022 -0.696226  0.746107  0.804926
# 7  0.042758 -1.058534  1.177088  0.516634
#
# A    0.067449
# B    1.364135
# C   -1.229525
# D   -1.215325
# Name: 3, dtype: float64
#           A         B         C         D
# 0 -0.842052  1.762629  0.887660  0.842017
# 1  0.380571  0.699405 -0.003666  0.866433
# 2  0.778278  0.457514  0.022936  1.169655
# 3  0.067449  1.364135 -1.229525 -1.215325
# 4  1.322887  1.112732  0.099083 -0.406288
# 5  0.075202 -0.099033 -0.415068 -0.889127
# 6  1.144022 -0.696226  0.746107  0.804926
# 7  0.042758 -1.058534  1.177088  0.516634
# 8  0.067449  1.364135 -1.229525 -1.215325

# %%
#Podział danych na grupy na podstawie wybranych kryteriów i łączenie wyników w strukturę danych

df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                   'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                      'D': np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one  1.013536 -0.821306
# 1  bar    one -1.250086 -0.044303
# 2  foo    two  0.832755  1.752561
# 3  bar  three -0.136326 -0.962769
# 4  foo    two  2.026449 -0.377986
# 5  bar    two -0.847184 -0.266720
# 6  foo    one  0.484254 -0.256364
# 7  foo  three -0.659120 -1.476820

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -2.233596 -1.273792
# foo  3.697874 -1.179914

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.250086 -0.044303
#     three -0.136326 -0.962769
#     two   -0.847184 -0.266720
# foo one    1.497790 -1.077670
#     three -0.659120 -1.476820
#     two    2.859204  1.374575

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],
                   ['one', 'two', 'one', 'two','one', 'two', 'one', 'two']]))

index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     1.657166  1.972078
#       two     1.100548  1.306074
# baz   one     1.039695 -0.370224
#       two    -0.604045 -1.329952

# %%
#Metoda stack () „kompresuje” poziom w kolumnach DataFrame.
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    1.657166
#                B    1.972078
#        two     A    1.100548
#                B    1.306074
# baz    one     A    1.039695
#                B   -0.370224
#        two     A   -0.604045
#                B   -1.329952
# dtype: float64

# %%
#Operacja odwrotna do stack()
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  1.657166  1.100548
#       B  1.972078  1.306074
# baz   A  1.039695 -0.604045
#       B -0.370224 -1.329952

# %%
#Przygotowanie danych
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                       'B': ['A', 'B', 'C'] * 4,
                       'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D': np.random.randn(12),
                       'E': np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.305678  0.323215
# 1     one  B  foo  0.166803  0.806729
# 2     two  C  foo  0.116965  2.088009
# 3   three  A  bar -0.374717 -0.158215
# 4     one  B  bar  0.215640  0.874771
# 5     one  C  bar  0.954542  0.519227
# 6     two  A  foo  0.690773  0.751688
# 7   three  B  foo -1.414160 -0.652337
# 8     one  C  foo -0.572680 -0.138742
# 9     one  A  bar -1.080836  1.131483
# 10    two  B  bar  0.556361  0.680547
# 11  three  C  bar  0.787884 -0.073124

# %%
#Tworzyć tabeli przestawych
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -1.080836  0.305678
#       B  0.215640  0.166803
#       C  0.954542 -0.572680
# three A -0.374717       NaN
#       B       NaN -1.414160
#       C  0.787884       NaN
# two   A       NaN  0.690773
#       B  0.556361       NaN
#       C       NaN  0.116965

# %%
##Serie "czasowe"
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min').sum()
# Out:
# 2012-01-01    23948
# Freq: 5T, dtype: int64

# %%
#Reprezentacje serii czasowych
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.895692
# 2012-03-07   -0.430725
# 2012-03-08   -0.234404
# 2012-03-09    1.321783
# 2012-03-10    0.611451
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.895692
# 2012-03-07 00:00:00+00:00   -0.430725
# 2012-03-08 00:00:00+00:00   -0.234404
# 2012-03-09 00:00:00+00:00    1.321783
# 2012-03-10 00:00:00+00:00    0.611451
# Freq: D, dtype: float64

# %%
#Zmiana na inną stefę czasową
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    0.895692
# 2012-03-06 19:00:00-05:00   -0.430725
# 2012-03-07 19:00:00-05:00   -0.234404
# 2012-03-08 19:00:00-05:00    1.321783
# 2012-03-09 19:00:00-05:00    0.611451
# Freq: D, dtype: float64

# %%
#Zmiana między reprezentacjami przedziałów czasowych:
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)

print(ts,'\n')
ps = ts.to_period()
print(ps, '\n')
ps.to_timestamp()
# Out:
# 2012-01-31    2.003279
# 2012-02-29    0.377403
# 2012-03-31    0.214339
# 2012-04-30    0.077129
# 2012-05-31    0.339264
# Freq: M, dtype: float64
#
# 2012-01    2.003279
# 2012-02    0.377403
# 2012-03    0.214339
# 2012-04    0.077129
# 2012-05    0.339264
# Freq: M, dtype: float64
# 2012-01-01    2.003279
# 2012-02-01    0.377403
# 2012-03-01    0.214339
# 2012-04-01    0.077129
# 2012-05-01    0.339264
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

ts = pd.Series(np.random.randn(len(prng)), prng)

ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

ts.head()
# Out:
# 1990-03-01 09:00   -2.454174
# 1990-06-01 09:00   -0.809621
# 1990-09-01 09:00    0.970425
# 1990-12-01 09:00   -0.189052
# 1991-03-01 09:00   -0.346432
# Freq: H, dtype: float64

# %%
#Konwersja surowych danych na kategoryczny typ
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],"raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})
print(df)
print("____________")
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e
# ____________
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
#Zamiana nazw kategorii
df["grade"].cat.categories = ["very good", "good", "very bad"]
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): [very good, good, very bad]

# %%
#Sortowanie według kategorii
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good
# 1   2         b       good
# 2   3         b       good
# 5   6         e   very bad

# %%
df.groupby("grade").size()
# Out:
# grade
# very good    3
# good         2
# very bad     1
# dtype: int64

# %%
#Generowanie wykresu
import matplotlib.pyplot as plt

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
df = df.cumsum()

plt.figure()
df.plot()
plt.legend(loc='best')
